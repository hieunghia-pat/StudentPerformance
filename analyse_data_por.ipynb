# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('student-por.csv',sep=';')
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        4   0  11  11
# 1    ...      5        3      3     1     1      3        2   9  11  11
# 2    ...      4        3      2     2     3      3        6  12  13  12
# 3    ...      3        2      2     1     1      5        0  14  14  14
# 4    ...      4        3      2     1     2      5        0  11  13  13
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [649 rows x 33 columns]

# %% [markdown]
# ## Two-way ANOVA for family_atts_data

# %%
family_atts_data = data[["address", "Pstatus", "Medu", "Mjob", "Fedu", "Fjob", "guardian", "famsize", "famrel", "G3"]]

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
formula = "G3 ~ C(Medu) + C(Fedu) + C(Medu):C(Fedu)"
model = ols(formula, data=family_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                       sum_sq     df         F    PR(>F)
# C(Medu)           167.522061    4.0  4.230305  0.002187
# C(Fedu)            57.054487    4.0  1.440753  0.218949
# C(Medu):C(Fedu)    70.430287   16.0  0.444630  0.970205
# Residual         6217.273156  628.0       NaN       NaN

# %%
formula = "G3 ~ C(Mjob) + C(Fjob) + C(Mjob):C(Fjob)"
model = ols(formula, data=family_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                       sum_sq     df         F    PR(>F)
# C(Mjob)           235.864515    4.0  5.838276  0.000129
# C(Fjob)            74.549297    4.0  1.845294  0.118527
# C(Mjob):C(Fjob)    90.312013   16.0  0.558866  0.914332
# Residual         6302.350582  624.0       NaN       NaN

# %%
formula = "G3 ~ C(famrel) + C(famsize) + C(famrel):C(famsize)"
model = ols(formula, data=family_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                            sum_sq     df         F    PR(>F)
# C(famrel)              151.926827    4.0  3.693495  0.005537
# C(famsize)              14.581968    1.0  1.418010  0.234173
# C(famrel):C(famsize)    26.537582    4.0  0.645155  0.630468
# Residual              6571.096575  639.0       NaN       NaN

# %%
formula = "G3 ~ C(Pstatus) + C(address) + C(Pstatus):C(address)"
model = ols(formula, data=family_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                             sum_sq     df          F    PR(>F)
# C(Pstatus)                1.558193    1.0   0.153302  0.695529
# C(address)              191.617564    1.0  18.852245  0.000016
# C(Pstatus):C(address)    15.750858    1.0   1.549644  0.213640
# Residual               6555.894298  645.0        NaN       NaN

# %% [markdown]
# ## Two-way ANOVA for school attributes

# %%
school_atts_data = data[["school", "reason", "traveltime", "studytime", "failures", "schoolsup", "famsup", "activities", "paid", "internet", "nursery", "higher", "G3"]]

# %%
formula = "G3 ~ C(school) + C(reason) + C(school):C(reason)"
model = ols(formula, data=school_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                           sum_sq     df          F        PR(>F)
# C(school)             378.544255    1.0  40.034763  4.685308e-10
# C(reason)             139.634032    3.0   4.922556  2.180646e-03
# C(school):C(reason)    16.099591    3.0   0.567563  6.365432e-01
# Residual             6060.904288  641.0        NaN           NaN

# %%
formula = "G3 ~ C(activities) + C(studytime) + C(activities):C(studytime)"
model = ols(formula, data=school_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                                  sum_sq     df          F        PR(>F)
# C(activities)                 12.762743    1.0   1.305042  2.537207e-01
# C(studytime)                 453.661771    3.0  15.462922  1.009605e-09
# C(activities):C(studytime)    16.727217    3.0   0.570142  6.348284e-01
# Residual                    6268.698779  641.0        NaN           NaN

# %%
formula = "G3 ~ C(schoolsup) + C(famsup) + C(schoolsup):C(famsup)"
model = ols(formula, data=school_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                              sum_sq     df         F    PR(>F)
# C(schoolsup)              34.162122    1.0  3.286562  0.070314
# C(famsup)                 28.046149    1.0  2.698176  0.100951
# C(schoolsup):C(famsup)     0.953651    1.0  0.091746  0.762067
# Residual                6704.443527  645.0       NaN       NaN

# %%
formula = "G3 ~ C(internet) + C(famsup) + C(internet):C(famsup)"
model = ols(formula, data=school_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                             sum_sq     df          F    PR(>F)
# C(internet)             144.455549    1.0  14.209479  0.000179
# C(famsup)                15.938882    1.0   1.567840  0.210975
# C(internet):C(famsup)    37.943786    1.0   3.732369  0.053805
# Residual               6557.159965  645.0        NaN       NaN

# %%
formula = "G3 ~ C(higher)"
model = ols(formula, data=school_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                 sum_sq     df          F        PR(>F)
# C(higher)   746.245075    1.0  80.242453  3.499660e-18
# Residual   6017.021489  647.0        NaN           NaN

# %%
formula = "G3 ~ C(paid)"
model = ols(formula, data=school_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                sum_sq     df        F    PR(>F)
# C(paid)     20.382999    1.0  1.95581  0.162441
# Residual  6742.883565  647.0      NaN       NaN

# %% [markdown]
# ## Two-way ANOVA for personal attributes

# %%
personal_atts_data = data[["sex", "age", "romantic", "freetime", "goout", "Walc", "Dalc", "health", "G3"]]

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
formula = "G3 ~ C(sex) + C(age) + C(sex):C(age)"
model = ols(formula, data=personal_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1863: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 6
#   warnings.warn('covariance of constraints does not have full '
#                     sum_sq     df          F    PR(>F)
# C(sex)          111.641923    1.0  11.204843  0.000864
# C(age)          245.781261    7.0   3.523946  0.001941
# C(sex):C(age)   122.915282    7.0   1.762326  0.092149
# Residual       6316.998862  634.0        NaN       NaN

# %%
formula = "G3 ~ C(freetime) + C(goout) + C(freetime):C(goout)"
model = ols(formula, data=personal_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                            sum_sq     df         F    PR(>F)
# C(freetime)            118.170918    4.0  2.992411  0.018303
# C(goout)               215.989129    4.0  5.469435  0.000248
# C(freetime):C(goout)   203.363493   16.0  1.287430  0.198858
# Residual              6160.472002  624.0       NaN       NaN

# %%
formula = "G3 ~ C(sex) + C(health) + C(sex):C(health)"
model = ols(formula, data=personal_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                        sum_sq     df         F    PR(>F)
# C(sex)              88.169991    1.0  8.584195  0.003512
# C(health)           76.467891    4.0  1.861221  0.115589
# C(sex):C(health)    10.818414    4.0  0.263319  0.901492
# Residual          6563.297491  639.0       NaN       NaN

# %%
formula = "G3 ~ C(age) + C(health) + C(age):C(health)"
model = ols(formula, data=personal_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1863: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1863: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1863: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 22
#   warnings.warn('covariance of constraints does not have full '
#                        sum_sq     df         F    PR(>F)
# C(age)             170.524629    7.0  2.439397  0.063460
# C(health)          135.669091    4.0  3.396364  0.017621
# C(age):C(health)   290.886044   28.0  1.040299  0.411138
# Residual          6161.576345  617.0       NaN       NaN

# %%
formula = "G3 ~ C(Dalc)"
model = ols(formula, data=personal_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                sum_sq     df         F    PR(>F)
# C(Dalc)    327.513973    4.0  8.193253  0.000002
# Residual  6435.752591  644.0       NaN       NaN

# %%
formula = "G3 ~ C(Walc)"
model = ols(formula, data=personal_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                sum_sq     df         F    PR(>F)
# C(Walc)    224.801060    4.0  5.535392  0.000219
# Residual  6538.465504  644.0       NaN       NaN

# %%
formula = "G3 ~ C(romantic)"
model = ols(formula, data=personal_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                   sum_sq     df         F    PR(>F)
# C(romantic)    55.494352    1.0  5.352723  0.021002
# Residual     6707.772211  647.0       NaN       NaN

# %% [markdown]
# ## Two-way ANOVA for school-reports attributes

# %%
schoolreport_atts_data = data[["absences", "G3"]]

# %%
formula = "G3 ~ absences"
model = ols(formula, data=schoolreport_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                sum_sq     df         F    PR(>F)
# absences    56.474168    1.0  5.448027  0.019896
# Residual  6706.792396  647.0       NaN       NaN

# %% [markdown]
# ## Two-way ANOVA for all attributes

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
anova_results = []
for att_idx_1 in range(len(data.columns[:-3])):
    for att_idx_2 in range(att_idx_1+1, len(data.columns[:-3])):
        formula = f"G3 ~ C({data.columns[att_idx_1]}) + C({data.columns[att_idx_2]}) + C({data.columns[att_idx_1]}):C({data.columns[att_idx_2]})"
        model = ols(formula, data=data).fit()
        anova_result = sm.stats.anova_lm(model, typ=2)
        anova_result.loc[:, "att1"] = data.columns[att_idx_1]
        anova_result.loc[:, "att2"] = data.columns[att_idx_2]
        anova_results.append(anova_result)
# Out:
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 1, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1900: RuntimeWarning: invalid value encountered in true_divide
#   F /= J
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 1, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 12
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 12
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 6
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 1, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 18
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 20
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 6
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 1, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 22
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 22
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 20
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 18
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 16
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 14, but rank is 12
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 13
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 16
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 16
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 1, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 6
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 1, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 6
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 1, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 6
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 1, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 6
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 1, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 6
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 6
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 1, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 6
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 6
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 22
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 22
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 22
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 18
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 20
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 22
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 161, but rank is 62
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 17
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 21
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 17
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 18
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 16
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 21
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 16, but rank is 14
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 16, but rank is 15
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 7
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 92, but rank is 65
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 16, but rank is 14
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 12, but rank is 11
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 12, but rank is 11
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 6
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 92, but rank is 60
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 12, but rank is 10
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 12, but rank is 10
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 16, but rank is 14
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 7
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 92, but rank is 55
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 8, but rank is 6
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 12, but rank is 11
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 12, but rank is 11
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 12, but rank is 8
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 16, but rank is 14
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 16, but rank is 15
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 92, but rank is 47
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 9, but rank is 8
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 9, but rank is 8
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 8
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 69, but rank is 44
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 11
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 46, but rank is 33
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 9, but rank is 7
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 1, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 12, but rank is 11
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 12, but rank is 11
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 69, but rank is 34
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# ...
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 69, but rank is 35
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 12, but rank is 10
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 12, but rank is 11
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 69, but rank is 28
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 1, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 9
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 9
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 18
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 21
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 1, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 8
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 8
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 1, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 17
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 18
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 13
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 21
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 16
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 22
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 13
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 22
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 17
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 20
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 16, but rank is 15
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 92, but rank is 58
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 16, but rank is 15
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 92, but rank is 59
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 7
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 92, but rank is 64
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 16, but rank is 14
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 16, but rank is 15
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 92, but rank is 40
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 6
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 92, but rank is 58
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 92, but rank is 57
#   warnings.warn('covariance of constraints does not have full '

# %%
anova_results[0]
# Out:
#                        sum_sq     df          F        PR(>F)    att1 att2
# C(school)          592.717214    1.0  63.112993  8.715777e-15  school  sex
# C(sex)             158.771329    1.0  16.906096  4.435182e-05  school  sex
# C(school):C(sex)     0.435583    1.0   0.046381  8.295524e-01  school  sex
# Residual          6057.430999  645.0        NaN           NaN  school  sex

# %%
effect_atts = []
for result in anova_results:
    if result["PR(>F)"][2] <= 0.05:
        effect_atts.append({
            "attribute_1": result["att1"][2],
            "attribute_2": result["att2"][2],
            "P": result["PR(>F)"][2]
        })

# %%
effect_atts
# Out:
# [{'attribute_1': 'school',
#   'attribute_2': 'famsize',
#   'P': 0.020623360197044794},
#  {'attribute_1': 'school',
#   'attribute_2': 'activities',
#   'P': 0.02841855461890062},
#  {'attribute_1': 'school', 'attribute_2': 'Dalc', 'P': 0.03312923187989444},
#  {'attribute_1': 'school', 'attribute_2': 'Walc', 'P': 0.002530609167849999},
#  {'attribute_1': 'sex', 'attribute_2': 'Pstatus', 'P': 2.3883929553451873e-05},
#  {'attribute_1': 'sex', 'attribute_2': 'Walc', 'P': 0.0010290817550304802},
#  {'attribute_1': 'age', 'attribute_2': 'address', 'P': 0.04032828498718007},
#  {'attribute_1': 'age', 'attribute_2': 'reason', 'P': 0.04442694551785726},
#  {'attribute_1': 'age',
#   'attribute_2': 'failures',
#   'P': 1.3952379563853445e-08},
#  {'attribute_1': 'address',
#   'attribute_2': 'internet',
#   'P': 0.011411885516921202},
#  {'attribute_1': 'address', 'attribute_2': 'Dalc', 'P': 0.04947492077540862},
#  {'attribute_1': 'address', 'attribute_2': 'Walc', 'P': 0.030139679288515464},
#  {'attribute_1': 'Pstatus',
#   'attribute_2': 'failures',
#   'P': 0.018539529460322512},
#  {'attribute_1': 'Medu', 'attribute_2': 'reason', 'P': 0.0027038211943902265},
#  {'attribute_1': 'Medu',
#   'attribute_2': 'failures',
#   'P': 1.4115060359725806e-17},
#  {'attribute_1': 'Medu', 'attribute_2': 'nursery', 'P': 0.012751788942790747},
#  {'attribute_1': 'Medu', 'attribute_2': 'Dalc', 'P': 0.0001759290222736966},
#  {'attribute_1': 'Fedu',
#   'attribute_2': 'studytime',
#   'P': 3.012678974931302e-07},
#  {'attribute_1': 'Fedu',
#   'attribute_2': 'failures',
#   'P': 1.1790574037046281e-07},
#  {'attribute_1': 'Fedu', 'attribute_2': 'famsup', 'P': 0.024630613270535468},
#  {'attribute_1': 'Fedu', 'attribute_2': 'freetime', 'P': 0.01069377433505274},
#  {'attribute_1': 'Fedu', 'attribute_2': 'Dalc', 'P': 0.0003087676971031521},
#  {'attribute_1': 'Fedu', 'attribute_2': 'Walc', 'P': 0.004991966513952941},
#  {'attribute_1': 'Mjob', 'attribute_2': 'higher', 'P': 0.03133667947742691},
#  {'attribute_1': 'Mjob', 'attribute_2': 'famrel', 'P': 0.011411333602116984},
#  {'attribute_1': 'Fjob',
#   'attribute_2': 'traveltime',
#   'P': 0.00287413534912391},
#  {'attribute_1': 'Fjob', 'attribute_2': 'failures', 'P': 0.005576938958691709},
#  {'attribute_1': 'Fjob', 'attribute_2': 'Dalc', 'P': 3.5395897563303e-05},
#  {'attribute_1': 'reason',
#   'attribute_2': 'nursery',
#   'P': 0.004845007175807606},
#  {'attribute_1': 'reason', 'attribute_2': 'famrel', 'P': 0.00894210415097732},
#  {'attribute_1': 'guardian',
#   'attribute_2': 'failures',
#   'P': 7.949001601659943e-07},
#  {'attribute_1': 'guardian', 'attribute_2': 'goout', 'P': 0.03372049053391281},
#  {'attribute_1': 'guardian', 'attribute_2': 'Dalc', 'P': 0.026827663903614143},
#  {'attribute_1': 'traveltime',
#   'attribute_2': 'higher',
#   'P': 0.024167624635698104},
#  {'attribute_1': 'failures',
#   'attribute_2': 'schoolsup',
#   'P': 0.015552645272097794},
#  {'attribute_1': 'failures',
#   'attribute_2': 'famrel',
#   'P': 4.45918027039843e-09},
#  {'attribute_1': 'failures',
#   'attribute_2': 'freetime',
#   'P': 1.2407244686811927e-08},
#  {'attribute_1': 'failures',
#   'attribute_2': 'goout',
#   'P': 0.00013231861274547543},
#  {'attribute_1': 'failures',
#   'attribute_2': 'absences',
#   'P': 0.026588330931487773},
#  {'attribute_1': 'famsup', 'attribute_2': 'Dalc', 'P': 0.0020850564876589766},
#  {'attribute_1': 'paid', 'attribute_2': 'romantic', 'P': 0.042470826993094464},
#  {'attribute_1': 'activities',
#   'attribute_2': 'goout',
#   'P': 0.047195843914758846},
#  {'attribute_1': 'higher', 'attribute_2': 'famrel', 'P': 0.013897546964945788},
#  {'attribute_1': 'higher', 'attribute_2': 'Dalc', 'P': 0.003697055245909683},
#  {'attribute_1': 'famrel', 'attribute_2': 'Walc', 'P': 0.004018186905561793},
#  {'attribute_1': 'goout', 'attribute_2': 'Dalc', 'P': 0.0005495954202164514}]

# %%
len(effect_atts)
# Out:
# 46

# %%
import json

json.dump(effect_atts, open("effect_attr.json", "w+"))

# %% [markdown]
# ## One-way ANOVA for all attributes

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
anova_results = []
for att_idx in range(len(data.columns[:-3])):
        formula = f"G3 ~ C({data.columns[att_idx]})"
        model = ols(formula, data=data).fit()
        anova_result = sm.stats.anova_lm(model, typ=2)
        anova_result.loc[:, "att"] = data.columns[att_idx]
        anova_results.append(anova_result)

# %%
anova_results[0]
# Out:
#                 sum_sq     df          F        PR(>F)     att
# C(school)   546.628653    1.0  56.890677  1.566199e-13  school
# Residual   6216.637911  647.0        NaN           NaN  school

# %%
effect_atts = []
for result in anova_results:
    if result["PR(>F)"][0] <= 0.05:
        effect_atts.append({
            "attribute": result["att"][0],
            "P": result["PR(>F)"][0]
        })

# %%
import json

json.dump(effect_atts, open("effect_single_attr.json", "w+"))

# %%
len(effect_atts)
# Out:
# 21
