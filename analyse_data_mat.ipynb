# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('student-mat.csv',sep=';')
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for feature in data.columns:
    if data[feature].dtype == "object":
        data[feature] = LabelEncoder().fit_transform(data[feature])

# %%
data.sample(10)
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 98        0    0   16        1        0        1     4     4     2     2  ...
# 161       0    1   15        0        0        1     3     2     2     2  ...
# 205       0    0   17        1        0        1     3     4     0     3  ...
# 85        0    0   15        1        0        1     4     4     3     3  ...
# 37        0    1   16        0        0        0     4     4     2     4  ...
# 323       0    0   17        1        0        1     3     1     3     3  ...
# 66        0    1   15        1        0        0     4     4     2     3  ...
# 168       0    0   16        1        0        1     2     2     2     2  ...
# 350       1    1   19        0        0        1     1     1     2     3  ...
# 269       0    0   18        0        0        1     2     1     2     2  ...
#
#      famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# ...

# %% [markdown]
# ## Two-way ANOVA for family_atts_data

# %%
family_atts_data = data[["address", "Pstatus", "Medu", "Mjob", "Fedu", "Fjob", "guardian", "famsize", "famrel", "G3"]]

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
formula = "G3 ~ C(Medu) + C(Fedu) + C(Medu):C(Fedu)"
model = ols(formula, data=family_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                       sum_sq     df          F        PR(>F)
# C(Medu)          2466.429047    4.0  30.792500  3.531550e-22
# C(Fedu)           798.434900    4.0   9.968179  1.124711e-07
# C(Medu):C(Fedu)   898.697365   16.0   2.804980  2.633004e-04
# Residual         7509.222125  375.0        NaN           NaN

# %%
formula = "G3 ~ C(Mjob) + C(Fjob) + C(Mjob):C(Fjob)"
model = ols(formula, data=family_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                       sum_sq     df         F    PR(>F)
# C(Mjob)            86.106914    4.0  1.051209  0.380589
# C(Fjob)            82.057835    4.0  1.001777  0.406501
# C(Mjob):C(Fjob)   477.265980   16.0  1.456638  0.113040
# Residual         7597.361381  371.0       NaN       NaN

# %%
formula = "G3 ~ C(famrel) + C(famsize) + C(famrel):C(famsize)"
model = ols(formula, data=family_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                            sum_sq     df         F    PR(>F)
# C(famrel)               36.200125    4.0  0.430066  0.786921
# C(famsize)              57.432538    1.0  2.729249  0.099341
# C(famrel):C(famsize)    77.214772    4.0  0.917330  0.453763
# Residual              8101.688306  385.0       NaN       NaN

# %%
formula = "G3 ~ C(Pstatus) + C(address) + C(Pstatus):C(address)"
model = ols(formula, data=family_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                             sum_sq     df         F    PR(>F)
# C(Pstatus)               23.719503    1.0  1.145298  0.285196
# C(address)               88.384424    1.0  4.267647  0.039503
# C(Pstatus):C(address)    55.952892    1.0  2.701689  0.101046
# Residual               8097.742951  391.0       NaN       NaN

# %% [markdown]
# ## Two-way ANOVA for school attributes

# %%
school_atts_data = data[["school", "reason", "traveltime", "studytime", "failures", "schoolsup", "famsup", "activities", "paid", "internet", "nursery", "higher", "G3"]]

# %%
formula = "G3 ~ C(school) + C(reason) + C(school):C(reason)"
model = ols(formula, data=school_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                           sum_sq     df         F    PR(>F)
# C(school)              12.605334    1.0  0.602513  0.438095
# C(reason)             125.752603    3.0  2.003586  0.112968
# C(school):C(reason)    30.870550    3.0  0.491853  0.688133
# Residual             8096.526530  387.0       NaN       NaN

# %%
formula = "G3 ~ C(activities) + C(studytime) + C(activities):C(studytime)"
model = ols(formula, data=school_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                                  sum_sq     df         F    PR(>F)
# C(activities)                  0.586357    1.0  0.028163  0.866813
# C(studytime)                 106.642948    3.0  1.707392  0.164962
# C(activities):C(studytime)   103.837375    3.0  1.662473  0.174605
# Residual                    8057.284974  387.0       NaN       NaN

# %%
formula = "G3 ~ C(schoolsup) + C(famsup) + C(schoolsup):C(famsup)"
model = ols(formula, data=school_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                              sum_sq     df         F    PR(>F)
# C(schoolsup)              51.774551    1.0  2.471784  0.116715
# C(famsup)                  7.773620    1.0  0.371123  0.542747
# C(schoolsup):C(famsup)    15.478701    1.0  0.738973  0.390517
# Residual                8189.975506  391.0       NaN       NaN

# %%
formula = "G3 ~ C(internet) + C(famsup) + C(internet):C(famsup)"
model = ols(formula, data=school_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                             sum_sq     df         F    PR(>F)
# C(internet)              87.895425    1.0  4.231155  0.040351
# C(famsup)                20.365893    1.0  0.980384  0.322716
# C(internet):C(famsup)    46.938796    1.0  2.259564  0.133599
# Residual               8122.394537  391.0       NaN       NaN

# %%
formula = "G3 ~ C(higher)"
model = ols(formula, data=school_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                 sum_sq     df          F    PR(>F)
# C(higher)   275.332861    1.0  13.534903  0.000267
# Residual   7994.576000  393.0        NaN       NaN

# %%
formula = "G3 ~ C(paid)"
model = ols(formula, data=school_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                sum_sq     df         F    PR(>F)
# C(paid)     86.033790    1.0  4.131451  0.042765
# Residual  8183.875071  393.0       NaN       NaN

# %% [markdown]
# ## Two-way ANOVA for personal attributes

# %%
personal_atts_data = data[["sex", "age", "romantic", "freetime", "goout", "Walc", "Dalc", "health", "G3"]]

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
formula = "G3 ~ C(sex) + C(age) + C(sex):C(age)"
model = ols(formula, data=personal_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1863: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
#                     sum_sq     df         F    PR(>F)
# C(sex)           69.687462    1.0  3.452278  0.063936
# C(age)          401.349672    7.0  2.840377  0.015621
# C(sex):C(age)   203.876287    7.0  1.442846  0.186683
# Residual       7690.840815  381.0       NaN       NaN

# %%
formula = "G3 ~ C(freetime) + C(goout) + C(freetime):C(goout)"
model = ols(formula, data=personal_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                            sum_sq     df         F    PR(>F)
# C(freetime)            269.241486    4.0  3.362728  0.010127
# C(goout)               343.684179    4.0  4.292490  0.002087
# C(freetime):C(goout)   335.609861   16.0  1.047911  0.404888
# Residual              7406.140958  370.0       NaN       NaN

# %%
formula = "G3 ~ C(sex) + C(health) + C(sex):C(health)"
model = ols(formula, data=personal_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                        sum_sq     df         F    PR(>F)
# C(sex)             104.394629    1.0  5.019625  0.025631
# C(health)          138.572757    4.0  1.665755  0.157196
# C(sex):C(health)    35.864309    4.0  0.431117  0.786157
# Residual          8006.958373  385.0       NaN       NaN

# %%
formula = "G3 ~ C(age) + C(health) + C(age):C(health)"
model = ols(formula, data=personal_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1863: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1863: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1863: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 28, but rank is 20
#   warnings.warn('covariance of constraints does not have full '
#                        sum_sq     df         F    PR(>F)
# C(age)              10.150948    7.0  0.070514  0.931927
# C(health)           18.181287    4.0  0.221021  0.801807
# ...

# %%
formula = "G3 ~ C(Dalc)"
model = ols(formula, data=personal_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                sum_sq     df         F    PR(>F)
# C(Dalc)    132.173885    4.0  1.583605  0.177864
# Residual  8137.734976  390.0       NaN       NaN

# %%
formula = "G3 ~ C(Walc)"
model = ols(formula, data=personal_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                sum_sq     df         F   PR(>F)
# C(Walc)     61.722394    4.0  0.733162  0.56975
# Residual  8208.186467  390.0       NaN      NaN

# %%
formula = "G3 ~ C(romantic)"
model = ols(formula, data=personal_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                   sum_sq     df         F    PR(>F)
# C(romantic)   139.696855    1.0  6.752698  0.009713
# Residual     8130.212006  393.0       NaN       NaN

# %% [markdown]
# ## Two-way ANOVA for school-reports attributes

# %%
schoolreport_atts_data = data[["absences", "G3"]]

# %%
formula = "G3 ~ absences"
model = ols(formula, data=schoolreport_atts_data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                sum_sq     df         F    PR(>F)
# absences     9.699600    1.0  0.461483  0.497332
# Residual  8260.209261  393.0       NaN       NaN

# %% [markdown]
# ## Two-way ANOVA for all attributes

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
anova_results = []
for att_idx_1 in range(len(data.columns[:-4])):
    for att_idx_2 in range(att_idx_1+1, len(data.columns[:-3])):
        formula = f"G3 ~ C({data.columns[att_idx_1]}) + C({data.columns[att_idx_2]}) + C({data.columns[att_idx_1]}):C({data.columns[att_idx_2]})"
        model = ols(formula, data=data).fit()
        anova_result = sm.stats.anova_lm(model, typ=2)
        anova_result.loc[:, "att1"] = data.columns[att_idx_1]
        anova_result.loc[:, "att2"] = data.columns[att_idx_2]
        anova_results.append(anova_result)
# Out:
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /home/nguyennghiauit/.local/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# ...

# %%
effect_atts = []
for result in anova_results:
    if result["PR(>F)"][2] <= 0.05:
        effect_atts.append({
            "attribute_1": result["att1"][2],
            "attribute_2": result["att2"][2],
            "P": result["PR(>F)"][2]
        })

# %%
effect_atts
# Out:
# [{'attribute_1': 'school', 'attribute_2': 'sex', 'P': 0.026823868016581327},
#  {'attribute_1': 'school', 'attribute_2': 'age', 'P': 0.048723304949419566},
#  {'attribute_1': 'school', 'attribute_2': 'Medu', 'P': 0.0012759640958197864},
#  {'attribute_1': 'school', 'attribute_2': 'Mjob', 'P': 0.003162753965521185},
#  {'attribute_1': 'school',
#   'attribute_2': 'failures',
#   'P': 1.2739076899536444e-11},
#  {'attribute_1': 'school', 'attribute_2': 'higher', 'P': 4.83157226003957e-05},
#  {'attribute_1': 'school',
#   'attribute_2': 'romantic',
#   'P': 0.0033037849611481304},
#  {'attribute_1': 'school',
#   'attribute_2': 'freetime',
#   'P': 0.029011099733800977},
#  {'attribute_1': 'school', 'attribute_2': 'goout', 'P': 0.0020064729671239816},
#  {'attribute_1': 'school',
#   'attribute_2': 'absences',
#   'P': 0.015664952360787233},
#  {'attribute_1': 'sex', 'attribute_2': 'Medu', 'P': 0.007174998611122334},
# ...

# %%
len(effect_atts)
# Out:
# 80

# %%
import json

json.dump(effect_atts, open("effect_pair_attr_mat.json", "w+"))

# %% [markdown]
# ## One-way ANOVA for all attributes (using statsmodels)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
anova_results = []
for att_idx in range(len(data.columns[:-4])):
        formula = f"G3 ~ C({data.columns[att_idx]})"
        model = ols(formula, data=data).fit()
        anova_result = sm.stats.anova_lm(model, typ=2)
        anova_result.loc[:, "att"] = data.columns[att_idx]
        anova_results.append(anova_result)

# %%
effect_atts = []
for result in anova_results:
    if result["PR(>F)"][0] <= 0.05:
        effect_atts.append({
            "attribute": result["att"][0],
            "P": result["PR(>F)"][0]
        })

# %%
len(effect_atts)
# Out:
# 11

# %%
import json

json.dump(effect_atts, open("effect_single_attr_mat.json", "w+"))

# %% [markdown]
# ## One-way ANOVA for all attributes (using scipy)
